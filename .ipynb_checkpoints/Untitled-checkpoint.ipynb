# %%
import os
import nglview as ng
import gromacs as gmx
import matplotlib.pyplot as plt
import numpy as np
import subprocess
import re
import mdtraj as md

# %% [markdown]
# ![image.png](attachment:a939b7a4-cdf4-4639-8081-da396778e801.png)

# %% [markdown]
# ![image.png](attachment:c6a51536-a920-4bb1-bb19-78b9d237e851.png)

# %% [markdown]
# Изменил single.gro файл, чтобы размерв ячейки были $0,41^3$, чтобы после размножения получить требуемую $L_0$. Частицу поместил в центр ячейки

# %%
# !cat single.gro
# Out:
# the only LJ atom in the cell
#     1
#     1RESID Ar    1   0.205   0.205   0.205  0.1324  0.1307  0.0385
#    0.41000   0.41000   0.41000

# %% [markdown]
# Размножил частицу в 1000 раз, получил ячейку размером $4.1^3$ нм

# %%
# !gmx genconf -f single.gro -nbox 10 10 10 -o 0/Ar_0
# Out:
#                :-) GROMACS - gmx genconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3
# Command line:
#   gmx genconf -f single.gro -nbox 10 10 10 -o 0/Ar_0
#
#
# GROMACS reminds you: "Cut It Deep and Cut It Wide" (The Walkabouts)

# %% [markdown]
# Визуализация изначальной структуры до проведения первого моделирования:

# %%
view = ng.show_structure_file("0/Ar_0.gro")
view
# Out:
# NGLWidget()

# %%
os.chdir("0")

# %%
for i in range(1, 12):
    os.mkdir(f"../{i}")
    os.chdir(f"../{i}")
    if i == 1:
        scale_factor = 1
    else: scale_factor = 1.2
    gmx.editconf(f=f"../{i-1}/Ar_{i-1}.gro",
            o=f"Ar_{i-1}_scaled",
            scale=f"{scale_factor}")
    gmx.grompp(f="../mdp.mdp",
          c=f"Ar_{i-1}_scaled",
          p="../Ar.top",
          o=f"Ar_{i}.tpr")
    gmx.mdrun(deffnm=f"Ar_{i}",
         v=True)
# Out:
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/1
# Command line:
#   gmx editconf -f ../0/Ar_0.gro -o Ar_0_scaled -scale 1
#
#
# GROMACS reminds you: "Everything Must Go" (Red Hot Chili Peppers)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/1
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_0_scaled -p ../Ar.top -o Ar_1.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "Everything Must Go" (Red Hot Chili Peppers)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/1
# Command line:
#   gmx mdrun -deffnm Ar_1 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_1.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.1709
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 1300, remaining wall clock time:   213 s
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 68.921 nm^3, corresponds to roughly 31000 electrons
# Velocities found
#     system size :  3.690  3.690  3.690 (nm)
#     center      :  2.050  2.050  2.050 (nm)
#     box vectors :  4.100  4.100  4.100 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :  68.92               (nm^3)
# new system size :  3.690  3.690  3.690
# new center      :  2.050  2.050  2.050 (nm)
# new box vectors :  4.100  4.100  4.100 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :  68.92               (nm^3)
# Setting the LD random seed to 2146351199
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to -352337961
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.092 nm, buffer size 0.005 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     4647.901      580.988      800.0
#                  (ns/day)    (hour/ns)
# Performance:      743.562        0.032
#
# GROMACS reminds you: "They don't have any beavers in India, so they have to simulate them" (The Tubes)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/2
# Command line:
#   gmx editconf -f ../1/Ar_1.gro -o Ar_1_scaled -scale 1.2
#
#
# GROMACS reminds you: "They don't have any beavers in India, so they have to simulate them" (The Tubes)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/2
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_1_scaled -p ../Ar.top -o Ar_2.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "They don't have any beavers in India, so they have to simulate them" (The Tubes)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/2
# Command line:
#   gmx mdrun -deffnm Ar_2 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_2.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.1339
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 700, remaining wall clock time:   250 s
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 68.921 nm^3, corresponds to roughly 31000 electrons
# Velocities found
#     system size :  4.095  4.095  4.095 (nm)
#     center      :  2.050  2.058  2.058 (nm)
#     box vectors :  4.100  4.100  4.100 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :  68.92               (nm^3)
# new system size :  4.914  4.914  4.914
# new center      :  2.460  2.470  2.470 (nm)
# new box vectors :  4.920  4.920  4.920 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  : 119.10               (nm^3)
# Setting the LD random seed to 2113794719
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to -88180641
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     4007.228      500.904      800.0
#                  (ns/day)    (hour/ns)
# Performance:      862.442        0.028
#
# GROMACS reminds you: "Don't Push Me, Cause I'm Close to the Edge" (Tricky)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/3
# Command line:
#   gmx editconf -f ../2/Ar_2.gro -o Ar_2_scaled -scale 1.2
#
#
# GROMACS reminds you: "Don't Push Me, Cause I'm Close to the Edge" (Tricky)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/3
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_2_scaled -p ../Ar.top -o Ar_3.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "Don't Push Me, Cause I'm Close to the Edge" (Tricky)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/3
# Command line:
#   gmx mdrun -deffnm Ar_3 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_3.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0999
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 200, will finish Mon Jan 12 19:04:22 2026
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 119.095 nm^3, corresponds to roughly 53500 electrons
# Velocities found
#     system size :  4.914  4.908  4.883 (nm)
#     center      :  2.440  2.435  2.504 (nm)
#     box vectors :  4.920  4.920  4.920 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 119.10               (nm^3)
# new system size :  5.897  5.890  5.860
# new center      :  2.928  2.922  3.005 (nm)
# new box vectors :  5.904  5.904  5.904 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  : 205.80               (nm^3)
# Setting the LD random seed to -1266689113
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to -1300611121
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     4410.266      551.283      800.0
#                  (ns/day)    (hour/ns)
# Performance:      783.626        0.031
#
# GROMACS reminds you: "Your Proposal is Accepted" (Men In Black)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/4
# Command line:
#   gmx editconf -f ../3/Ar_3.gro -o Ar_3_scaled -scale 1.2
#
#
# GROMACS reminds you: "Your Proposal is Accepted" (Men In Black)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/4
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_3_scaled -p ../Ar.top -o Ar_4.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "Your Proposal is Accepted" (Men In Black)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/4
# Command line:
#   gmx mdrun -deffnm Ar_4 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_4.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0869
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 205.797 nm^3, corresponds to roughly 92600 electrons
# Velocities found
#     system size :  5.900  5.887  5.896 (nm)
#     center      :  2.917  2.934  2.952 (nm)
#     box vectors :  5.904  5.904  5.904 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 205.80               (nm^3)
# new system size :  7.080  7.064  7.075
# new center      :  3.500  3.521  3.542 (nm)
# new box vectors :  7.085  7.085  7.085 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  : 355.62               (nm^3)
# Setting the LD random seed to -617384001
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to -1149259779
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     3732.001      466.500      800.0
#                  (ns/day)    (hour/ns)
# Performance:      926.045        0.026
#
# GROMACS reminds you: "I Wrapped a Newspaper Round My Head" (F. Zappa)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/5
# Command line:
#   gmx editconf -f ../4/Ar_4.gro -o Ar_4_scaled -scale 1.2
#
#
# GROMACS reminds you: "I Wrapped a Newspaper Round My Head" (F. Zappa)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/5
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_4_scaled -p ../Ar.top -o Ar_5.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "The determined Real Programmer can write FORTRAN programs in any language." (Ed Post)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/5
# Command line:
#   gmx mdrun -deffnm Ar_5 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_5.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0869
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 900, remaining wall clock time:   193 s
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 355.617 nm^3, corresponds to roughly 160000 electrons
# Velocities found
#     system size :  7.060  7.060  7.076 (nm)
#     center      :  3.542  3.521  3.564 (nm)
#     box vectors :  7.085  7.085  7.085 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 355.62               (nm^3)
# new system size :  8.472  8.472  8.491
# new center      :  4.251  4.225  4.276 (nm)
# new box vectors :  8.502  8.502  8.502 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  : 614.51               (nm^3)
# Setting the LD random seed to 1036972015
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to 1475133401
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     4457.973      557.247      800.0
#                  (ns/day)    (hour/ns)
# Performance:      775.240        0.031
#
# GROMACS reminds you: "Given enough eyeballs, all bugs are shallow." (Linus Torvalds, on the power of open source)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/6
# Command line:
#   gmx editconf -f ../5/Ar_5.gro -o Ar_5_scaled -scale 1.2
#
#
# GROMACS reminds you: "Given enough eyeballs, all bugs are shallow." (Linus Torvalds, on the power of open source)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/6
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_5_scaled -p ../Ar.top -o Ar_6.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "Given enough eyeballs, all bugs are shallow." (Linus Torvalds, on the power of open source)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/6
# Command line:
#   gmx mdrun -deffnm Ar_6 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_6.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0869
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 500, remaining wall clock time:   258 s
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 614.506 nm^3, corresponds to roughly 276500 electrons
# Velocities found
#     system size :  8.494  8.484  8.462 (nm)
#     center      :  4.276  4.268  4.242 (nm)
#     box vectors :  8.502  8.502  8.502 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 614.51               (nm^3)
# new system size : 10.193 10.181 10.154
# new center      :  5.132  5.121  5.091 (nm)
# new box vectors : 10.202 10.202 10.202 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :1061.87               (nm^3)
# Setting the LD random seed to 871366645
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to -739272965
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2643.212      330.402      800.0
#                  (ns/day)    (hour/ns)
# Performance:     1307.500        0.018
#
# GROMACS reminds you: "What is a Unix or Linux sysadmin's favourite hangout place? Foo Bar." (Anonymous)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/7
# Command line:
#   gmx editconf -f ../6/Ar_6.gro -o Ar_6_scaled -scale 1.2
#
#
# GROMACS reminds you: "What is a Unix or Linux sysadmin's favourite hangout place? Foo Bar." (Anonymous)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/7
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_6_scaled -p ../Ar.top -o Ar_7.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "What is a Unix or Linux sysadmin's favourite hangout place? Foo Bar." (Anonymous)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/7
# Command line:
#   gmx mdrun -deffnm Ar_7 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_7.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0869
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 300, remaining wall clock time:   238 s
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 1061.87 nm^3, corresponds to roughly 477800 electrons
# Velocities found
#     system size : 10.173 10.166 10.172 (nm)
#     center      :  5.101  5.030  4.928 (nm)
#     box vectors : 10.202 10.202 10.202 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :1061.87               (nm^3)
# new system size : 12.208 12.199 12.206
# new center      :  6.121  6.036  5.913 (nm)
# new box vectors : 12.243 12.243 12.243 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :1834.91               (nm^3)
# Setting the LD random seed to -537134209
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to -537985026
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2748.428      343.554      800.0
#                  (ns/day)    (hour/ns)
# Performance:     1257.446        0.019
#
# GROMACS reminds you: "Right Between the Eyes" (F. Zappa)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/8
# Command line:
#   gmx editconf -f ../7/Ar_7.gro -o Ar_7_scaled -scale 1.2
#
#
# GROMACS reminds you: "Right Between the Eyes" (F. Zappa)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/8
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_7_scaled -p ../Ar.top -o Ar_8.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "Right Between the Eyes" (F. Zappa)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/8
# Command line:
#   gmx mdrun -deffnm Ar_8 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_8.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0869
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 1600, remaining wall clock time:   162 s
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 1834.9 nm^3, corresponds to roughly 825700 electrons
# Velocities found
#     system size : 12.216 12.235 12.203 (nm)
#     center      :  6.146  6.011  6.293 (nm)
#     box vectors : 12.243 12.243 12.243 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :1834.90               (nm^3)
# new system size : 14.659 14.682 14.644
# new center      :  7.375  7.213  7.551 (nm)
# new box vectors : 14.691 14.691 14.691 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :3170.72               (nm^3)
# Setting the LD random seed to -168376321
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to 1605827311
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2100.433      262.554      800.0
#                  (ns/day)    (hour/ns)
# Performance:     1645.375        0.015
#
# GROMACS reminds you: "The difficulty lies, not in the new ideas, but in escaping the old ones." (John Maynard Keynes)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/9
# Command line:
#   gmx editconf -f ../8/Ar_8.gro -o Ar_8_scaled -scale 1.2
#
#
# GROMACS reminds you: "The difficulty lies, not in the new ideas, but in escaping the old ones." (John Maynard Keynes)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/9
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_8_scaled -p ../Ar.top -o Ar_9.tpr
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 3170.72 nm^3, corresponds to roughly 1426800 electrons
# Velocities found
#     system size : 14.672 14.648 14.648 (nm)
#     center      :  7.375  7.448  7.243 (nm)
#     box vectors : 14.691 14.691 14.691 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :3170.72               (nm^3)
# new system size : 17.606 17.578 17.578
# new center      :  8.850  8.938  8.691 (nm)
# new box vectors : 17.629 17.629 17.629 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :5479.00               (nm^3)
# Setting the LD random seed to 2141585403
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to -78776597
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "The difficulty lies, not in the new ideas, but in escaping the old ones." (John Maynard Keynes)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/9
# Command line:
#   gmx mdrun -deffnm Ar_9 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_9.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0869
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     1502.335      187.792      800.0
#                  (ns/day)    (hour/ns)
# Performance:     2300.419        0.010
#
# GROMACS reminds you: "Oh My God ! It's the Funky Shit" (Beastie Boys)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/10
# Command line:
#   gmx editconf -f ../9/Ar_9.gro -o Ar_9_scaled -scale 1.2
#
#
# GROMACS reminds you: "Oh My God ! It's the Funky Shit" (Beastie Boys)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/10
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_9_scaled -p ../Ar.top -o Ar_10.tpr
#
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "Oh My God ! It's the Funky Shit" (Beastie Boys)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/10
# Command line:
#   gmx mdrun -deffnm Ar_10 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_10.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0869
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 1900, remaining wall clock time:   107 s
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 5479 nm^3, corresponds to roughly 2465500 electrons
# Velocities found
#     system size : 17.624 17.606 17.598 (nm)
#     center      :  8.674  8.779  8.956 (nm)
#     box vectors : 17.629 17.629 17.629 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :5479.00               (nm^3)
# new system size : 21.149 21.127 21.118
# new center      : 10.408 10.535 10.747 (nm)
# new box vectors : 21.155 21.155 21.155 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :9467.72               (nm^3)
# Setting the LD random seed to -139756033
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to -1884385
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     1639.157      204.895      800.0
#                  (ns/day)    (hour/ns)
# Performance:     2108.400        0.011
#
# GROMACS reminds you: "My Head Goes Pop Pop Pop Pop Pop" (F. Black)
#
#                :-) GROMACS - gmx editconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/11
# Command line:
#   gmx editconf -f ../10/Ar_10.gro -o Ar_10_scaled -scale 1.2
#
#
# GROMACS reminds you: "My Head Goes Pop Pop Pop Pop Pop" (F. Black)
#
#                 :-) GROMACS - gmx grompp, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/11
# Command line:
#   gmx grompp -f ../mdp.mdp -c Ar_10_scaled -p ../Ar.top -o Ar_11.tpr
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 1000 atoms
# Volume: 9467.72 nm^3, corresponds to roughly 4260400 electrons
# Velocities found
#     system size : 21.123 21.136 21.149 (nm)
#     center      : 10.303 10.514 10.472 (nm)
#     box vectors : 21.155 21.155 21.155 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :9467.72               (nm^3)
# new system size : 25.348 25.363 25.379
# new center      : 12.363 12.617 12.566 (nm)
# new box vectors : 25.386 25.386 25.386 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :16360.22               (nm^3)
# Setting the LD random seed to 1778129655
#
# Generated 1 of the 1 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'ARGON'
#
# Setting gen_seed to 1861081549
#
# Velocities were taken from a Maxwell distribution at 250 K
# Analysing residue names:
# There are:  1000    Protein residues
# Analysing Protein...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 250 K
#
# Calculated rlist for 1x1 atom pair-list as 1.087 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.087 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 18 Mb of data
# Number of degrees of freedom in T-Coupling group System is 2997.00
#
# GROMACS reminds you: "My Head Goes Pop Pop Pop Pop Pop" (F. Black)
#
#                 :-) GROMACS - gmx mdrun, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3/11
# Command line:
#   gmx mdrun -deffnm Ar_11 -v
#
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file Ar_11.tpr, VERSION 2025.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1.0869 to 1.0869
#
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'bulk lennard-jonesium, argon'
# 2000000 steps,   5000.0 ps.
# step 1999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 2000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     1853.641      231.705      800.0
#                  (ns/day)    (hour/ns)
# Performance:     1864.439        0.013
#
# GROMACS reminds you: "All You Need is Greed" (Aztec Camera)

# %% [markdown]
# Посмотрим на систему после первого моделирования:

# %%
ng.show_structure_file("1/Ar_1.gro")
# Out:
# NGLWidget()

# %% [markdown]
# ... и после последнего:

# %%
ng.show_structure_file("11/Ar_11.gro")
# Out:
# NGLWidget()

# %% [markdown]
# # Построение $P-V$ диаграммы

# %% [markdown]
# Посмотрел зависимость давления от времени в первом моделировании, чтобы понять, сколько времени в начале пропускать и не брать для расчета средних значений давления.

# %%
os.chdir("/home/ivank/tasks/task_3")

# %%
os.getcwd()
# Out:
# '/home/ivank/tasks/task_3'

# %%
cmd = f'echo -e "10\\n0" | gmx energy -f 1/Ar_1.edr -s 1/Ar_1.tpr -o 1/Ar_1_result_to_check.xvg -nmol 1000'
result = subprocess.run(
    cmd,
    shell=True,
    capture_output=True,
    text=True,
    check=False
)

# %%
output = result.stdout + result.stderr
match = re.search(r'Pressure\s+(-?\d+\.?\d*)', output)
if match:
    print(f"Average pressure in first experiment: {float(match.group(1))} bar")
# Out:
# Average pressure in first experiment: 1129.86 bar

# %%
pressure = np.genfromtxt([i for i in open('1/Ar_1_result_to_check.xvg').read().splitlines()
                           if not i.startswith(('#','@'))])
plt.plot(*pressure.T)
plt.xlabel('ps')
plt.ylabel('pressure')
plt.show()

# %% [markdown]
# После 50 пикосекунд система приходит в равновесие, поэтому для усреднения буду брать значения давления после этого промежутка времени.

# %%
skip = 50

# %% [markdown]
# Запросил значения давления из .edr файлов для каждого моделирования, из вывода в консоль получил средние значения давлений и их сохраним в файл average_pressures.txt

# %%
p_list = []
V_list = []
for i in range(1, 12):
    cmd = f'echo -e "10\\n0" | gmx energy -f {i}/Ar_{i}.edr -s {i}/Ar_{i}.tpr -o {i}/Ar_{i}_result.xvg -b 50 -nmol 1000'
    result = subprocess.run(
        cmd,
        shell=True,
        capture_output=True,
        text=True,
        check=False
    )
    output = result.stdout + result.stderr
    match = re.search(r'Pressure\s+(-?\d+\.?\d*)', output)
    if match:
        p_list.append(float(match.group(1)))
    else: print("Not found!")

    with open(f"{i}/Ar_{i}.gro") as gro:
        lines = gro.readlines()
    last_line = lines[-1].strip()
    length = last_line.split(" ")[0]
    volume = float(length)**3 
    V_list.append(volume)

# %%
with open("average_pressures_bar.txt", 'w') as file:
    file.write(' '.join(str(x) for x in p_list))

# %%
with open("average_pressures_bar.txt") as file:
    p_list_str = file.read().split(" ")
p_list = [float(p) for p in p_list_str]
V_list = []
for i in range(1, 12):
    with open(f"{i}/Ar_{i}.gro") as gro:
            lines = gro.readlines()
    last_line = lines[-1].strip()
    length = last_line.split(" ")[0]
    volume = float(length)**3 
    V_list.append(volume)

# %% [markdown]
# Объем в $нм^3$

# %%
V_list
# Out:
# [68.92099999999998,
#  119.09548799999999,
#  205.79700326399998,
#  355.61722164019204,
#  614.5065589942519,
#  1061.8667094436537,
#  1834.9047746412425,
#  3170.7180404992364,
#  5479.002638725202,
#  9467.716559717152,
#  16360.214215191234]

# %% [markdown]
# Давление в $бар$

# %%
p_list
# Out:
# [1130.02,
#  291.574,
#  148.888,
#  87.7686,
#  52.5294,
#  31.2065,
#  18.3416,
#  10.7198,
#  6.24473,
#  3.62344,
#  2.10131]

# %% [markdown]
# Перевел давление в $Па$, а объем в $м^3$

# %%
p_list_Pa = [p*100000 for p in p_list]
V_list_m3 = [V*1e-27 for V in V_list]

# %% [markdown]
# Исходя из числа частиц в ячейке посчитал молярный объем

# %%
N_a = 6e23
N = 1000
V_list_m3_molar = [V/(N/N_a) for V in V_list_m3]

# %% [markdown]
# По уравнению состояния идеального газа, посчитал, какой у него будет объем при каждом давлении, полученном из результатов моделирований.

# %%
T = 250
R = 8.31
p_list_ig_Pa = [R*T/V for V in V_list_m3_molar]

# %%
V_list_m3_molar
# Out:
# [4.135259999999999e-05,
#  7.145729279999999e-05,
#  0.0001234782019584,
#  0.00021337033298411524,
#  0.00036870393539655113,
#  0.0006371200256661923,
#  0.0011009428647847457,
#  0.001902430824299542,
#  0.0032874015832351213,
#  0.005680629935830291,
#  0.00981612852911474]

# %%
p_list_ig_Pa
# Out:
# [50238679.06733798,
#  29073309.645450216,
#  16824831.97074665,
#  9736592.575663568,
#  5634602.184990492,
#  3260767.071051804,
#  1887018.9057505622,
#  1092023.9377244725,
#  631958.0822114039,
#  365716.482761229,
#  211641.483079415]

# %%
p_list_Pa
# Out:
# [113002000.0,
#  29157400.0,
#  14888800.0,
#  8776860.0,
#  5252940.0,
#  3120650.0,
#  1834160.0,
#  1071980.0,
#  624473.0,
#  362344.0,
#  210130.99999999997]

# %%
plt.close()
plt.plot(V_list_m3_molar, p_list_Pa, label="Ar")
plt.plot(V_list_m3_molar, p_list_ig_Pa, label="Ideal Gas")
plt.ylabel("Pressure, $Pa$")
plt.xlabel("Volume molar, $m^3$")
plt.legend()
plt.show()

# %%
V_list_result
# Out:
# [4.1352599999999986e+22,
#  7.14572928e+22,
#  1.234782019584e+23,
#  2.1337033298411523e+23,
#  3.687039353965511e+23,
#  6.371200256661922e+23,
#  1.1009428647847456e+24,
#  1.902430824299542e+24,
#  3.2874015832351213e+24,
#  5.680629935830291e+24,
#  9.81612852911474e+24]

# %%
V_list
# Out:
# [68.92099999999998,
#  119.09548799999999,
#  205.79700326399998,
#  355.61722164019204,
#  614.5065589942519,
#  1061.8667094436537,
#  1834.9047746412425,
#  3170.7180404992364,
#  5479.002638725202,
#  9467.716559717152,
#  16360.214215191234]

# %%
traj = md.load('1/Ar_1.xtc', top='1/Ar_0_scaled.gro')
view = ng.show_mdtraj(traj)
view
# Out:
# NGLWidget(max_frame=2000)
