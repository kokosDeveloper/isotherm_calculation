# %%
import os
import nglview as ng
import gromacs as gmx
import matplotlib.pyplot as plt
import numpy as np
import subprocess
import re
import mdtraj as md
# %matplotlib widget
# Out:
# /home/ivank/miniconda3/lib/python3.13/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# NOTE: Some configuration directories are not set up yet:
# 	/home/ivank/.gromacswrapper
# 	/home/ivank/.gromacswrapper/qscripts
# 	/home/ivank/.gromacswrapper/templates
# NOTE: You can create the configuration file and directories with:
# 	>>> import gromacs
# 	>>> gromacs.config.setup()

# %% [markdown]
# ![image.png](attachment:a939b7a4-cdf4-4639-8081-da396778e801.png)

# %% [markdown]
# ![image.png](attachment:c6a51536-a920-4bb1-bb19-78b9d237e851.png)

# %% [markdown]
# Изменил single.gro файл, чтобы размерв ячейки были $0,41^3$, чтобы после размножения получить требуемую $L_0$. Частицу поместил в центр ячейки

# %%
# !cat single.gro
# Out:
# the only LJ atom in the cell
#     1
#     1RESID Ar    1   0.205   0.205   0.205  0.1324  0.1307  0.0385
#    0.41000   0.41000   0.41000

# %% [markdown]
# Размножил частицу в 1000 раз, получил ячейку размером $4.1^3$ нм

# %%
# !gmx genconf -f single.gro -nbox 10 10 10 -o 0/Ar_0
# Out:
#                :-) GROMACS - gmx genconf, 2025.4-conda_forge (-:
#
# Executable:   /home/ivank/miniconda3/bin.AVX2_256/gmx
# Data prefix:  /home/ivank/miniconda3
# Working dir:  /home/ivank/tasks/task_3
# Command line:
#   gmx genconf -f single.gro -nbox 10 10 10 -o 0/Ar_0
#
#
# GROMACS reminds you: "Cut It Deep and Cut It Wide" (The Walkabouts)

# %% [markdown]
# Визуализация изначальной структуры до проведения первого моделирования:

# %%
from IPython.display import display
from IPython.display import Image

# %%
os.getcwd()
# Out:
# '/home/ivank/tasks/task_3'

# %%
import nglview as ng
from IPython.display import Image, display
import os

# Создаем view
view = ng.show_structure_file("0/Ar_0.gro")

# Показываем в ноутбуке
display(Image(filename="structure_0.png"))

# %%
view = ng.show_structure_file("0/Ar_0.gro")
display(view)
view.download_image(filename='/home/ivank/tasks/task_3/structure_1.png')
display(Image(filename='structure_1.png'))
# Out:
# NGLWidget()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 display(view)
#       3 view.download_image(filename='/home/ivank/tasks/task_3/structure_1.png')
# ----> 4 display(Image(filename='structure_1.png'))
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/display.py:1025, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1023 self.unconfined = unconfined
#    1024 self.alt = alt
# -> 1025 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1026         metadata=metadata)
#    1028 if self.width is None and self.metadata.get('width', {}):
#    1029     self.width = metadata['width']
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/display.py:343, in DisplayObject.__init__(self, data, url, filename, metadata)
#     340 elif self.metadata is None:
#     341     self.metadata = {}
# --> 343 self.reload()
#     344 self._check_data()
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/display.py:1060, in Image.reload(self)
#    1058 """Reload the raw data from file or URL."""
#    1059 if self.embed:
# -> 1060     super(Image,self).reload()
#    1061     if self.retina:
#    1062         self._retina_shape()
#
# File ~/miniconda3/lib/python3.13/site-packages/IPython/core/display.py:369, in DisplayObject.reload(self)
#     367 if self.filename is not None:
#     368     encoding = None if "b" in self._read_flags else "utf-8"
# --> 369     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     370         self.data = f.read()
#     371 elif self.url is not None:
#     372     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: 'structure_1.png'

# %%
os.chdir("0")

# %% [markdown]
# Провел 11 моделирований, в каждом объем ячейки увеличивался в $1.3^3$ по отношению к предыдущему. Результаты расчетов сохранены в папках с именами, соответствующими номеру расчета

# %%
for i in range(1, 12):
    os.mkdir(f"../{i}")
    os.chdir(f"../{i}")
    if i == 1:
        scale_factor = 1
    else: scale_factor = 1.2
    gmx.editconf(f=f"../{i-1}/Ar_{i-1}.gro",
            o=f"Ar_{i-1}_scaled",
            scale=f"{scale_factor}")
    gmx.grompp(f="../mdp.mdp",
          c=f"Ar_{i-1}_scaled",
          p="../Ar.top",
          o=f"Ar_{i}.tpr")
    gmx.mdrun(deffnm=f"Ar_{i}",
         v=True)

# %% [markdown]
# Посмотрим на систему после первого моделирования:

# %%
ng.show_structure_file("1/Ar_1.gro")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 ng.show_structure_file("1/Ar_1.gro")
#
# File ~/miniconda3/lib/python3.13/site-packages/nglview/show.py:216, in show_structure_file(path, **kwargs)
#     205 def show_structure_file(path, **kwargs):
#     206     '''Show structure file. Allowed are text-based structure
#     207     file formats that are by supported by NGL, including pdb,
#     208     gro, mol2, sdf.
#    (...)    214     >>> w # doctest: +SKIP
#     215     '''
# --> 216     structure = FileStructure(path)
#     217     return NGLWidget(structure, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/nglview/adaptor.py:80, in FileStructure.__init__(self, path)
#      78 super().__init__()
#      79 self.fm = FileManager(path)
# ---> 80 self.ext = self.fm.ext
#      81 self.params = {}
#      82 self.path = path
#
# File ~/miniconda3/lib/python3.13/site-packages/nglview/utils/py_utils.py:242, in FileManager.ext(self)
#     239 else:
#     240     if hasattr(self.src, 'read') or (not self.is_filename and
#     241                                      not self.is_url):
# --> 242         raise ValueError(
#     243             "you must provide file extension if using file-like object or text content"
#     244         )
#     245     if self.is_compressed:
#     246         return self.src.split('.')[-2]
#
# ValueError: you must provide file extension if using file-like object or text content

# %% [markdown]
# ... и после последнего:

# %%
ng.show_structure_file("11/Ar_11.gro")
# Out:
# NGLWidget()

# %% [markdown]
# Как и ожидалось, плотность в последнем случае много меньше исходной плотности

# %% [markdown]
# # Построение $P-V$ диаграммы

# %% [markdown]
# Посмотрел зависимость давления от времени в первом моделировании, чтобы понять, сколько времени в начале пропускать и не брать для расчета средних значений давления.

# %%
os.chdir("/home/ivank/tasks/task_3")

# %%
os.getcwd()
# Out:
# '/home/ivank/tasks/task_3'

# %%
cmd = f'echo -e "10\\n0" | gmx energy -f 1/Ar_1.edr -s 1/Ar_1.tpr -o 1/Ar_1_result_to_check.xvg -nmol 1000'
result = subprocess.run(
    cmd,
    shell=True,
    capture_output=True,
    text=True,
    check=False
)

# %%
output = result.stdout + result.stderr
match = re.search(r'Pressure\s+(-?\d+\.?\d*)', output)
if match:
    print(f"Average pressure in first experiment: {float(match.group(1))} bar")
# Out:
# Average pressure in first experiment: 1129.86 bar

# %%
pressure = np.genfromtxt([i for i in open('1/Ar_1_result_to_check.xvg').read().splitlines()
                           if not i.startswith(('#','@'))])
plt.plot(*pressure.T)
plt.xlabel('ps')
plt.ylabel('pressure')
plt.show()

# %% [markdown]
# После 50 пикосекунд система приходит в равновесие, поэтому для усреднения буду брать значения давления после этого промежутка времени.

# %%
skip = 50

# %% [markdown]
# Запросил значения давления из .edr файлов для каждого моделирования, из вывода в консоль получил средние значения давлений и их сохраним в файл average_pressures.txt

# %%
p_list = []
V_list = []
for i in range(1, 12):
    cmd = f'echo -e "10\\n0" | gmx energy -f {i}/Ar_{i}.edr -s {i}/Ar_{i}.tpr -o {i}/Ar_{i}_result.xvg -b 50 -nmol 1000'
    result = subprocess.run(
        cmd,
        shell=True,
        capture_output=True,
        text=True,
        check=False
    )
    output = result.stdout + result.stderr
    match = re.search(r'Pressure\s+(-?\d+\.?\d*)', output)
    if match:
        p_list.append(float(match.group(1)))
    else: print("Not found!")

    with open(f"{i}/Ar_{i}.gro") as gro:
        lines = gro.readlines()
    last_line = lines[-1].strip()
    length = last_line.split(" ")[0]
    volume = float(length)**3 
    V_list.append(volume)

# %%
# если оперативная память очистилась, запустить, чтобы загрузить в память V и p
with open("average_pressures_bar.txt") as file:
    p_list_str = file.read().split(" ")
p_list = [float(p) for p in p_list_str]
V_list = []
for i in range(1, 12):
    with open(f"{i}/Ar_{i}.gro") as gro:
            lines = gro.readlines()
    last_line = lines[-1].strip()
    length = last_line.split(" ")[0]
    volume = float(length)**3 
    V_list.append(volume)

# %% [markdown]
# Объем в $нм^3$

# %%
V_list
# Out:
# [68.92099999999998,
#  119.09548799999999,
#  205.79700326399998,
#  355.61722164019204,
#  614.5065589942519,
#  1061.8667094436537,
#  1834.9047746412425,
#  3170.7180404992364,
#  5479.002638725202,
#  9467.716559717152,
#  16360.214215191234]

# %% [markdown]
# Давление в $бар$

# %%
p_list
# Out:
# [1130.02,
#  291.574,
#  148.888,
#  87.7686,
#  52.5294,
#  31.2065,
#  18.3416,
#  10.7198,
#  6.24473,
#  3.62344,
#  2.10131]

# %% [markdown]
# Перевел давление в $Па$, а объем в $м^3$

# %%
p_list_Pa = [p*100000 for p in p_list]
V_list_m3 = [V*1e-27 for V in V_list]

# %% [markdown]
# Исходя из числа частиц в ячейке посчитал молярный объем

# %%
N_a = 6e23
N = 1000
V_list_m3_molar = [V/(N/N_a) for V in V_list_m3]

# %% [markdown]
# По уравнению состояния идеального газа, посчитал, какой у него будет объем при каждом давлении, полученном из результатов моделирований.

# %%
T = 250
R = 8.31
p_list_ig_Pa = [R*T/V for V in V_list_m3_molar]

# %% [markdown]
# На одном графике изобразил изотермы (T=250 К) для исследуемого газа (Ar) и для идеального газа.

# %%
plt.close()
plt.plot(V_list_m3_molar, p_list_Pa, label="Ar")
plt.plot(V_list_m3_molar, p_list_ig_Pa, label="Ideal Gas")
plt.ylabel("Pressure, $Pa$")
plt.xlabel("Volume molar, $m^3$")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Изотермы совпадают, поэтому поведение аргона можно описать уравнением идеального газа

# %% [markdown]
# # Расчет вириальных коэффициентов

# %% [markdown]
# Разложение фактора сжимаемости по степеням обратного молярного объема:
# $$
# Z = \frac{pV_m}{RT} = 1+\frac{B}{V_m} + \frac{C}{V_m^2} + ...
# $$
# $$
# (Z-1)V_m = B + \frac{C}{V_m}
# $$
# Если построить зависимость $y = (Z-1)V_m$ от $x = \frac{1}{V_m}$, то должна получиться прямая, при этом отрезок, отсекаемый на оси y, будет соответствовать вириальному $B$, а тангенс угла наклона - коэффициенту $C$

# %% [markdown]
# Посчитал фактор сжимаемости для каждого давления

# %%
z_list = []
for i in list(range(len(V_list_m3_molar))):
    V_m = V_list_m3_molar[i]
    p = p_list_Pa[i]
    z = p*V_m/(R*T)
    z_list.append(z)

# %%
z_list
# Out:
# [2.2493027702527066,
#  1.0028923557577472,
#  0.8849300858330811,
#  0.9014303445270574,
#  0.932264572997333,
#  0.9570294142455851,
#  0.9719881419367458,
#  0.9816451480301435,
#  0.9881557299097886,
#  0.9907784228488525,
#  0.9928630103255881]

# %% [markdown]
# Построил зависимость фактора сжимаемости от давления

# %%
plt.close()
plt.plot(p_list_Pa, z_list)
plt.xlabel("Pressure, Pa")
plt.ylabel("Z")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Построил зависимость $(Z-1)V_m$ от $\frac{1}{V_m}$, чтобы найти вириальные коэффициенты

# %%
x_list = []
y_list = []
for i in list(range(len(V_list_m3_molar))):
    V_m = V_list_m3_molar[i]
    z = z_list[i]
    x_list.append(1/V_m)
    y = (z-1)*V_m
    y_list.append(y)

plt.close()
plt.plot(x_list, y_list)
plt.xlabel(r"$\frac{1}{V_m}$")
plt.ylabel(r"$(Z-1)V_m$")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Зависимость не линейная, не понятно, как определить вириальные коэффициенты
